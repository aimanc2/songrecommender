# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = "70d5be9c5cd2437eacc8392f04833c36"
client_secret = "450e54f685384e5e812e3d2b4b3cfafb"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret
))

# %%
results = sp.search(q="artist:Shakira track:Dai Dai", type="track", limit=1) # Search up the track 
print(type(results))
print(results)
# Out:
# <class 'dict'>
# ...

# %%
track_id = results['tracks']['items'][0]['id']

# %%
import pandas as pd

spotify_df = pd.read_csv('data/external/spotify-tracks-dataset.csv')

# %%
print(spotify_df.shape)
print(spotify_df.columns)
spotify_df.head()
# Out:
# (114000, 22)
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'track_id', 'artists', 'album_name',
#        'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')
#    Unnamed: 0.1  Unnamed: 0                track_id                 artists  \
# 0             0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1             1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2             2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3             3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4             4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# ...

# %%
spotify_df = spotify_df.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
spotify_df
# Out:
#         Unnamed: 0.1                track_id                 artists  \
# 0                  0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                  1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                  2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                  3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                  4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...              ...                     ...                     ...
# 113995        113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996        113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997        113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998        113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999        113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
spotify_df['artists_clean'] = spotify_df['artists'].str.lower().str.strip()
spotify_df['track_name_clean'] = spotify_df['track_name'].str.lower().str.strip()

# %%
spotify_df
# Out:
#         Unnamed: 0.1                track_id                 artists  \
# 0                  0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                  1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                  2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                  3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                  4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...              ...                     ...                     ...
# 113995        113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996        113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997        113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998        113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999        113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
merged = df.merge(
    spotify_df,
    left_on=['Artist_clean', 'Title_clean'],
    right_on=['artists_clean', 'track_name_clean'],
    how='left',
    indicator=True
)
match_rate = (merged['_merge'] == 'both').mean() * 100
print(f"Match rate: {match_rate:.1f}%")
print(merged.shape)
# Out:
# Match rate: 30.7%
# (15094, 35)

# %%
merged
# Out:
#                    Artist and Title  Days    T10   Pk   (x?)  PkStreams  \
# 0      The Weeknd - Blinding Lights  2409  446.0    1  (x82)    8453567
# 1      The Weeknd - Blinding Lights  2409  446.0    1  (x82)    8453567
# 2      The Weeknd - Blinding Lights  2409  446.0    1  (x82)    8453567
# 3      The Weeknd - Blinding Lights  2409  446.0    1  (x82)    8453567
# 4      The Weeknd - Blinding Lights  2409  446.0    1  (x82)    8453567
# ...                             ...   ...    ...  ...    ...        ...
# 15089            Wisin - Adrenalina     1    NaN  188    NaN     124862
# 15090            Iggy Azalea - Work     1    NaN  196    NaN     120954
# 15091               Orup - Främling     1    NaN  199    NaN     120760
# 15092             Ed Sheeran - Nina     1    NaN  199    NaN     120515
# 15093        Take That - These Days     1    NaN  198    NaN     115382
#
#             Total       Artist            Title Artist_clean  ...  \
# ...

# %%
merged['_merge'].value_counts()
# Out:
# _merge
# left_only     10462
# both           4632
# right_only        0
# Name: count, dtype: int64

# %%
match_rate = (merged['_merge'] == 'both').mean() * 100
print(f"Match rate: {match_rate:.1f}%")
# Out:
# Match rate: 30.7%

# %%
print(df.shape)
df[['Artist', 'Title']].head(10)
# Out:
# (11795, 11)
#               Artist                                          Title
# 0         The Weeknd                                Blinding Lights
# 1         Ed Sheeran                                   Shape of You
# 2       Harry Styles                                      As It Was
# 3  The Neighbourhood                                Sweater Weather
# 4      Lewis Capaldi                              Someone You Loved
# 5         The Weeknd                                        Starboy
# 6      Billie Eilish                             BIRDS OF A FEATHER
# 7          Lady Gaga                               Die With A Smile
# 8        Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 9         Ed Sheeran                                        Perfect

# %%
df[['Artist', 'Artist_clean', 'Title', 'Title_clean']].sample(10)
# Out:
#                                 Artist                     Artist_clean  \
# 5973                      Lil Uzi Vert                     lil uzi vert
# 8402             La Maquinaria Norteña            la maquinaria norteña
# 10135                          MACHETE                          machete
# 2342                          Anuel AA                         anuel aa
# 10477                    Ariana Grande                    ariana grande
# 943                     StaySolidRocky                   staysolidrocky
# 11085  Tom Petty and the Heartbreakers  tom petty and the heartbreakers
# 7419                        Daði Freyr                       daði freyr
# 7608                                MØ                               mø
# 3222                              Møme                             møme
#
#                             Title                 Title_clean
# 5973                  Bean (Kobe)                 bean (kobe)
# ...

# %%
merged[merged['Artist'].str.contains('Weeknd', na=False)][['Artist', 'Title', '_merge']]
# Out:
#            Artist                                   Title     _merge
# 0      The Weeknd                         Blinding Lights       both
# 1      The Weeknd                         Blinding Lights       both
# 2      The Weeknd                         Blinding Lights       both
# 3      The Weeknd                         Blinding Lights       both
# 4      The Weeknd                         Blinding Lights       both
# ...           ...                                     ...        ...
# 12062  The Weeknd                       Without a Warning  left_only
# 12451  The Weeknd  Nothing Is Lost (You Give Me Strength)  left_only
# 12867  The Weeknd          Nothing Compares - Bonus Track  left_only
# 12914  The Weeknd                Missed You - Bonus Track  left_only
# 13682  The Weeknd             Final Lullaby - Bonus Track  left_only
#
# [111 rows x 3 columns]

# %%
final_df = merged[merged['_merge'] == 'both'].copy()
final_df = final_df.drop(columns=['_merge'])
print(final_df.shape)
final_df.to_csv('data/processed/final_matched_catalog.csv', index=False)
# Out:
# (4632, 34)
